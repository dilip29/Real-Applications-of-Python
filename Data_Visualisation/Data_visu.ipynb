# %%
import bokeh

# %%
from bokeh.plotting import figure
from bokeh.io import output_file,show

f=figure()

x=[1,4,5]
y=[2,3,6]

output_file("line.html")

f.triangle(x,y,size=[10,20,30],line_width=2)
show(f)

# %%
    from bokeh.plotting import figure, output_file, show
    
    plot = figure(plot_width=300, plot_height=300)
    plot.triangle(x=[1, 2, 3], y=[1, 2, 3], size=[10,20,25],
    color="#99D594", line_width=2)
    
    show(plot)

# %%
help(f.triangle)
# Out:
# Help on method Triangle:
#
# Triangle(x, y, size=4, angle=0.0, **kwargs) method of bokeh.plotting.figure.Figure instance
#     Configure and add :class:`~bokeh.models.markers.Triangle` glyphs to this Figure.
#
#     Args:
#         x (:class:`~bokeh.core.properties.NumberSpec` ) :
#             The x-axis coordinates for the center of the markers.
#
#             (default: None)
#
#         y (:class:`~bokeh.core.properties.NumberSpec` ) :
#             The y-axis coordinates for the center of the markers.
#
#             (default: None)
#
#         size (:class:`~bokeh.core.properties.ScreenDistanceSpec` ) :
#             The size (diameter) values for the markers in screen space units.
#
#             (default: 4)
#
#         angle (:class:`~bokeh.core.properties.AngleSpec` ) :
#             The angles to rotate the markers.
#
#             (default: 0.0)
#
#
#     Keyword Args:
# ...

# %%
f.circle([1,2,3],[2,5,6])
show(f)

# %%
help(f.circle)
# Out:
# Help on method Circle:
#
# Circle(x, y, **kwargs) method of bokeh.plotting.figure.Figure instance
#     Configure and add :class:`~bokeh.models.markers.Circle` glyphs to this Figure.
#
#     Args:
#         x (:class:`~bokeh.core.properties.NumberSpec` ) :
#             The x-axis coordinates for the center of the markers.
#
#             (default: None)
#
#         y (:class:`~bokeh.core.properties.NumberSpec` ) :
#             The y-axis coordinates for the center of the markers.
#
#             (default: None)
#
#
#     Keyword Args:
#         angle (:class:`~bokeh.core.properties.AngleSpec` ) :
#             The angles to rotate the markers.
#
#             (default: 0.0)
#
#         angle_units (:class:`~bokeh.core.properties.Enum` ( :class:`~bokeh.core.enums.AngleUnits`  )) :
#             (default: 'rad')
#
#         fill_alpha (:class:`~bokeh.core.properties.NumberSpec` ) :
#             The fill alpha values for the markers.
#
#             (default: 1.0)
#
# ...

# %%
f.circle([1,5,6],[6,8,9],size=25)
show(f)

# %%
from bokeh.plotting import figure
from bokeh.io import output_file,show
import pandas

f=figure()

df=pandas.read_csv("data.csv")
x=df["x"]
y=df["y"]

output_file("line_using_csv.html")

f.triangle(x,y,size=[10,20,30],line_width=2)
show(f)
# Out:
# /home/dsp/.local/lib/python3.6/site-packages/bokeh/models/sources.py:110: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('size', 3), ('x', 5), ('y', 5)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
